# %% [markdown]
# <a href="https://colab.research.google.com/github/galang-ajus/latihan-ke-2/blob/main/latihan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definisikan list kosong untuk menyimpan angka
list = []

# %%
# input 10 angka
for i in range(10):
    angka = int(input("Masukkan angka: "))
    list.append(angka)
# Out:
# Masukkan angka: 1
# Masukkan angka: 6
# Masukkan angka: 9
# Masukkan angka: 0
# Masukkan angka: 5
# Masukkan angka: 3
# Masukkan angka: 5
# Masukkan angka: 7
# Masukkan angka: 2
# Masukkan angka: 1

# %%
# tampilkan nilai maksimum, minimum, dan rata-rata
print("List:", list)
print("Nilai maksimum:", max(list))
print("Nilai minimum:", min(list))
print("Rata-rata:", sum(list)/len(list))
# Out:
# List: [1, 6, 9, 0, 5, 3, 5, 7, 2, 1]
# Nilai maksimum: 9
# Nilai minimum: 0
# Rata-rata: 3.9

# %%
#buat grafik batang menggunakan matplotlib
import matplotlib.pyplot as plt
plt.bar(range(len(list)), list)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()
